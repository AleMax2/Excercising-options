# %%
from keras.layers import *
from keras.models import Model
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
tf.config.experimental.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
print(tf.__version__)
print(tf.config.list_physical_devices())
# Out:
# 2.7.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
np.random.seed(0)
tf.random.set_seed(0)

num_classes = 10
input_shape = (32, 32, 3)

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=0, # try 180 or less
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True)
datagen.fit(x_train)
datagen_test = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True)
datagen_test.fit(x_train)

def split_data(images, labels, train_size=0.9, shuffle=True):
    # 1. Get the total size of the dataset
    size = len(images)
    # 2. Make an indices array and shuffle it, if required
    indices = np.arange(size)
    if shuffle:
        np.random.shuffle(indices)
    # 3. Get the size of training samples
    train_samples = int(size * train_size)
    # 4. Split data into training and validation sets
    x_train, y_train = images[indices[:train_samples]], labels[indices[:train_samples]]
    x_valid, y_valid = images[indices[train_samples:]], labels[indices[train_samples:]]
    return x_train, x_valid, y_train, y_valid


# Splitting data into training and validation sets
x_train, x_valid, y_train, y_valid = split_data(x_train, y_train)

# %%
def building_block(X, filter_size, filters, stride=1):

    # Save the input value for shortcut
    X_shortcut = X

    # Reshape shortcut for later adding if dimensions change
    if stride > 1:
        X_shortcut = BatchNormalization(axis=3)(X_shortcut)
        X_shortcut = Activation('relu')(X_shortcut)
        X_shortcut = Conv2D(filters, (1, 1), strides=stride, padding='same')(X_shortcut)
        

    # First layer of the block
    X = BatchNormalization(axis=3)(X)
    X = Activation('relu')(X)
    X = Conv2D(filters, kernel_size = filter_size, strides=stride, padding='same')(X)
    #X = Dropout(0.2)(X)
    

    # Second layer of the block
    
    X = BatchNormalization(axis=3)(X)
    X = Activation('relu')(X)
    X = Conv2D(filters, kernel_size = filter_size, strides=(1, 1), padding='same')(X)
    X = add([X, X_shortcut])  # Add shortcut value to main path
    

    return X

# %%
# Full model
# Full model
def create_model(input_shape, classes, name):

    # Define the input
    X_input = Input(input_shape)

    # Stage 1
    X = Conv2D(filters=16, kernel_size=3, strides=(1, 1), padding='same')(X_input)
    X = BatchNormalization(axis=3)(X)
    X = Activation('relu')(X)

    # Stage 2
    X = building_block(X, filter_size=3, filters=16, stride=1)
    X = building_block(X, filter_size=3, filters=16, stride=1)
    X = building_block(X, filter_size=3, filters=16, stride=1)
    X = building_block(X, filter_size=3, filters=16, stride=1)
    X = building_block(X, filter_size=3, filters=16, stride=1)

    # Stage 3
    X = building_block(X, filter_size=3, filters=32, stride=2)  # dimensions change (stride=2)
    X = building_block(X, filter_size=3, filters=32, stride=1)
    X = building_block(X, filter_size=3, filters=32, stride=1)
    X = building_block(X, filter_size=3, filters=32, stride=1)
    X = building_block(X, filter_size=3, filters=32, stride=1)

    # Stage 4
    X = building_block(X, filter_size=3, filters=64, stride=2)  # dimensions change (stride=2)
    X = building_block(X, filter_size=3, filters=64, stride=1)
    X = building_block(X, filter_size=3, filters=64, stride=1)
    X = building_block(X, filter_size=3, filters=64, stride=1)
    X = building_block(X, filter_size=3, filters=64, stride=1)

    # Average pooling and output layer
    X = GlobalAveragePooling2D()(X)
    X = Dense(classes, activation='softmax')(X)

    # Create model
    model = Model(inputs=X_input, outputs=X, name=name)

    return model

# %%
batch_size = 128
epochs = 60

def scheduler(epoch, lr):
    if epoch == 0:
        return lr
    if (epoch % 30) == 0:
        return lr * 0.32
    else:
        return lr

# %%
classes = y_train.shape[1]
# opt = tf.keras.optimizers.Adam(learning_rate=0.1, beta_1=0.9, beta_2=0.999, epsilon=1e-07, decay=0.0)
#opt = keras.optimizers.SGD(learning_rate=0.01, momentum=0.9, decay=0.001)
opt = keras.optimizers.Adadelta(learning_rate=0.1, rho=0.9, epsilon= 0.001, decay=0.002)
ResNet47 = create_model(input_shape= input_shape, classes=classes, name='ResNet50')
ResNet47.compile(optimizer=opt, loss='categorical_crossentropy', metrics = ['accuracy'])
schedule = keras.callbacks.LearningRateScheduler(scheduler)

# %%
ResNet47.summary()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_20 (InputLayer)          [(None, 32, 32, 3)]  0           []
#
#  conv2d_489 (Conv2D)            (None, 32, 32, 16)   448         ['input_20[0][0]']
#
#  batch_normalization_489 (Batch  (None, 32, 32, 16)  64          ['conv2d_489[0][0]']
#  Normalization)
#
#  activation_489 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_489[0][0]']
#
#  batch_normalization_490 (Batch  (None, 32, 32, 16)  64          ['activation_489[0][0]']
#  Normalization)
#
#  activation_490 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_490[0][0]']
#
#  conv2d_490 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_490[0][0]']
#
#  batch_normalization_491 (Batch  (None, 32, 32, 16)  64          ['conv2d_490[0][0]']
#  Normalization)
#
#  activation_491 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_491[0][0]']
#
#  conv2d_491 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_491[0][0]']
#
#  add_217 (Add)                  (None, 32, 32, 16)   0           ['conv2d_491[0][0]',
#                                                                   'activation_489[0][0]']
#
#  batch_normalization_492 (Batch  (None, 32, 32, 16)  64          ['add_217[0][0]']
#  Normalization)
#
#  activation_492 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_492[0][0]']
#
#  conv2d_492 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_492[0][0]']
#
#  batch_normalization_493 (Batch  (None, 32, 32, 16)  64          ['conv2d_492[0][0]']
#  Normalization)
#
#  activation_493 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_493[0][0]']
#
#  conv2d_493 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_493[0][0]']
#
#  add_218 (Add)                  (None, 32, 32, 16)   0           ['conv2d_493[0][0]',
#                                                                   'add_217[0][0]']
#
#  batch_normalization_494 (Batch  (None, 32, 32, 16)  64          ['add_218[0][0]']
#  Normalization)
#
#  activation_494 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_494[0][0]']
#
#  conv2d_494 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_494[0][0]']
#
#  batch_normalization_495 (Batch  (None, 32, 32, 16)  64          ['conv2d_494[0][0]']
#  Normalization)
#
#  activation_495 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_495[0][0]']
#
#  conv2d_495 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_495[0][0]']
#
#  add_219 (Add)                  (None, 32, 32, 16)   0           ['conv2d_495[0][0]',
#                                                                   'add_218[0][0]']
#
#  batch_normalization_496 (Batch  (None, 32, 32, 16)  64          ['add_219[0][0]']
#  Normalization)
#
#  activation_496 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_496[0][0]']
#
#  conv2d_496 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_496[0][0]']
#
#  batch_normalization_497 (Batch  (None, 32, 32, 16)  64          ['conv2d_496[0][0]']
#  Normalization)
#
#  activation_497 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_497[0][0]']
#
#  conv2d_497 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_497[0][0]']
#
#  add_220 (Add)                  (None, 32, 32, 16)   0           ['conv2d_497[0][0]',
#                                                                   'add_219[0][0]']
#
#  batch_normalization_498 (Batch  (None, 32, 32, 16)  64          ['add_220[0][0]']
#  Normalization)
#
#  activation_498 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_498[0][0]']
#
#  conv2d_498 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_498[0][0]']
#
#  batch_normalization_499 (Batch  (None, 32, 32, 16)  64          ['conv2d_498[0][0]']
#  Normalization)
#
#  activation_499 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_499[0][0]']
#
#  conv2d_499 (Conv2D)            (None, 32, 32, 16)   2320        ['activation_499[0][0]']
#
#  add_221 (Add)                  (None, 32, 32, 16)   0           ['conv2d_499[0][0]',
#                                                                   'add_220[0][0]']
#
#  batch_normalization_501 (Batch  (None, 32, 32, 16)  64          ['add_221[0][0]']
#  Normalization)
#
#  activation_501 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_501[0][0]']
#
#  conv2d_501 (Conv2D)            (None, 16, 16, 32)   4640        ['activation_501[0][0]']
#
#  batch_normalization_502 (Batch  (None, 16, 16, 32)  128         ['conv2d_501[0][0]']
#  Normalization)
#
#  batch_normalization_500 (Batch  (None, 32, 32, 16)  64          ['add_221[0][0]']
#  Normalization)
#
#  activation_502 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_502[0][0]']
#
#  activation_500 (Activation)    (None, 32, 32, 16)   0           ['batch_normalization_500[0][0]']
#
#  conv2d_502 (Conv2D)            (None, 16, 16, 32)   9248        ['activation_502[0][0]']
#
#  conv2d_500 (Conv2D)            (None, 16, 16, 32)   544         ['activation_500[0][0]']
#
#  add_222 (Add)                  (None, 16, 16, 32)   0           ['conv2d_502[0][0]',
#                                                                   'conv2d_500[0][0]']
#
#  batch_normalization_503 (Batch  (None, 16, 16, 32)  128         ['add_222[0][0]']
#  Normalization)
#
#  activation_503 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_503[0][0]']
#
#  conv2d_503 (Conv2D)            (None, 16, 16, 32)   9248        ['activation_503[0][0]']
#
#  batch_normalization_504 (Batch  (None, 16, 16, 32)  128         ['conv2d_503[0][0]']
#  Normalization)
#
#  activation_504 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_504[0][0]']
#
#  conv2d_504 (Conv2D)            (None, 16, 16, 32)   9248        ['activation_504[0][0]']
#
#  add_223 (Add)                  (None, 16, 16, 32)   0           ['conv2d_504[0][0]',
#                                                                   'add_222[0][0]']
#
#  batch_normalization_505 (Batch  (None, 16, 16, 32)  128         ['add_223[0][0]']
#  Normalization)
#
#  activation_505 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_505[0][0]']
#
#  conv2d_505 (Conv2D)            (None, 16, 16, 32)   9248        ['activation_505[0][0]']
#
#  batch_normalization_506 (Batch  (None, 16, 16, 32)  128         ['conv2d_505[0][0]']
#  Normalization)
#
#  activation_506 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_506[0][0]']
#
#  conv2d_506 (Conv2D)            (None, 16, 16, 32)   9248        ['activation_506[0][0]']
#
#  add_224 (Add)                  (None, 16, 16, 32)   0           ['conv2d_506[0][0]',
#                                                                   'add_223[0][0]']
#
#  batch_normalization_507 (Batch  (None, 16, 16, 32)  128         ['add_224[0][0]']
#  Normalization)
#
#  activation_507 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_507[0][0]']
#
#  conv2d_507 (Conv2D)            (None, 16, 16, 32)   9248        ['activation_507[0][0]']
#
#  batch_normalization_508 (Batch  (None, 16, 16, 32)  128         ['conv2d_507[0][0]']
#  Normalization)
#
#  activation_508 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_508[0][0]']
#
#  conv2d_508 (Conv2D)            (None, 16, 16, 32)   9248        ['activation_508[0][0]']
#
#  add_225 (Add)                  (None, 16, 16, 32)   0           ['conv2d_508[0][0]',
#                                                                   'add_224[0][0]']
#
#  batch_normalization_509 (Batch  (None, 16, 16, 32)  128         ['add_225[0][0]']
#  Normalization)
#
#  activation_509 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_509[0][0]']
#
#  conv2d_509 (Conv2D)            (None, 16, 16, 32)   9248        ['activation_509[0][0]']
#
#  batch_normalization_510 (Batch  (None, 16, 16, 32)  128         ['conv2d_509[0][0]']
#  Normalization)
#
#  activation_510 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_510[0][0]']
#
#  conv2d_510 (Conv2D)            (None, 16, 16, 32)   9248        ['activation_510[0][0]']
#
#  add_226 (Add)                  (None, 16, 16, 32)   0           ['conv2d_510[0][0]',
#                                                                   'add_225[0][0]']
#
#  batch_normalization_512 (Batch  (None, 16, 16, 32)  128         ['add_226[0][0]']
#  Normalization)
#
#  activation_512 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_512[0][0]']
#
#  conv2d_512 (Conv2D)            (None, 8, 8, 64)     18496       ['activation_512[0][0]']
#
#  batch_normalization_513 (Batch  (None, 8, 8, 64)    256         ['conv2d_512[0][0]']
#  Normalization)
#
#  batch_normalization_511 (Batch  (None, 16, 16, 32)  128         ['add_226[0][0]']
#  Normalization)
#
#  activation_513 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_513[0][0]']
#
#  activation_511 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_511[0][0]']
#
#  conv2d_513 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_513[0][0]']
#
#  conv2d_511 (Conv2D)            (None, 8, 8, 64)     2112        ['activation_511[0][0]']
#
#  add_227 (Add)                  (None, 8, 8, 64)     0           ['conv2d_513[0][0]',
#                                                                   'conv2d_511[0][0]']
#
#  batch_normalization_514 (Batch  (None, 8, 8, 64)    256         ['add_227[0][0]']
#  Normalization)
#
#  activation_514 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_514[0][0]']
#
#  conv2d_514 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_514[0][0]']
#
#  batch_normalization_515 (Batch  (None, 8, 8, 64)    256         ['conv2d_514[0][0]']
#  Normalization)
#
#  activation_515 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_515[0][0]']
#
#  conv2d_515 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_515[0][0]']
#
#  add_228 (Add)                  (None, 8, 8, 64)     0           ['conv2d_515[0][0]',
#                                                                   'add_227[0][0]']
#
#  batch_normalization_516 (Batch  (None, 8, 8, 64)    256         ['add_228[0][0]']
#  Normalization)
#
#  activation_516 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_516[0][0]']
#
#  conv2d_516 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_516[0][0]']
#
#  batch_normalization_517 (Batch  (None, 8, 8, 64)    256         ['conv2d_516[0][0]']
#  Normalization)
#
#  activation_517 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_517[0][0]']
#
#  conv2d_517 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_517[0][0]']
#
#  add_229 (Add)                  (None, 8, 8, 64)     0           ['conv2d_517[0][0]',
#                                                                   'add_228[0][0]']
#
#  batch_normalization_518 (Batch  (None, 8, 8, 64)    256         ['add_229[0][0]']
#  Normalization)
#
#  activation_518 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_518[0][0]']
#
#  conv2d_518 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_518[0][0]']
#
#  batch_normalization_519 (Batch  (None, 8, 8, 64)    256         ['conv2d_518[0][0]']
#  Normalization)
#
#  activation_519 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_519[0][0]']
#
#  conv2d_519 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_519[0][0]']
#
#  add_230 (Add)                  (None, 8, 8, 64)     0           ['conv2d_519[0][0]',
#                                                                   'add_229[0][0]']
#
#  batch_normalization_520 (Batch  (None, 8, 8, 64)    256         ['add_230[0][0]']
#  Normalization)
#
#  activation_520 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_520[0][0]']
#
#  conv2d_520 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_520[0][0]']
#
#  batch_normalization_521 (Batch  (None, 8, 8, 64)    256         ['conv2d_520[0][0]']
#  Normalization)
#
#  activation_521 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_521[0][0]']
#
#  conv2d_521 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_521[0][0]']
#
#  add_231 (Add)                  (None, 8, 8, 64)     0           ['conv2d_521[0][0]',
#                                                                   'add_230[0][0]']
#
#  global_average_pooling2d_18 (G  (None, 64)          0           ['add_231[0][0]']
#  lobalAveragePooling2D)
#
#  dense_18 (Dense)               (None, 10)           650         ['global_average_pooling2d_18[0][
#                                                                  0]']
#
# ==================================================================================================
# Total params: 470,218
# Trainable params: 467,946
# Non-trainable params: 2,272
# __________________________________________________________________________________________________

# %%
history=ResNet47.fit(datagen.flow(x_train, y_train, batch_size=batch_size), steps_per_epoch=len(x_train) / batch_size, epochs=epochs, validation_data=datagen_test.flow(x_valid,y_valid,batch_size=100),validation_steps=50,callbacks=[schedule])

score = ResNet47.evaluate(datagen_test.flow(x_test, y_test,batch_size=100,shuffle=False),steps=len(x_test)/100)
print("Test accuracy:", score[1])
# Out:
# Epoch 1/60
# 351/351 [==============================] - 52s 135ms/step - loss: 1.8997 - accuracy: 0.3264 - val_loss: 1.5579 - val_accuracy: 0.4270 - lr: 0.1000
# Epoch 2/60
# 351/351 [==============================] - 47s 133ms/step - loss: 1.4179 - accuracy: 0.4808 - val_loss: 1.3493 - val_accuracy: 0.5208 - lr: 0.1000
# Epoch 3/60
# 351/351 [==============================] - 47s 133ms/step - loss: 1.2375 - accuracy: 0.5499 - val_loss: 1.2454 - val_accuracy: 0.5696 - lr: 0.1000
# Epoch 4/60
# 351/351 [==============================] - 47s 134ms/step - loss: 1.1070 - accuracy: 0.6016 - val_loss: 1.1825 - val_accuracy: 0.5878 - lr: 0.1000
# Epoch 5/60
# 351/351 [==============================] - 46s 132ms/step - loss: 1.0183 - accuracy: 0.6338 - val_loss: 1.1173 - val_accuracy: 0.6234 - lr: 0.1000
# Epoch 6/60
# 351/351 [==============================] - 47s 133ms/step - loss: 0.9528 - accuracy: 0.6601 - val_loss: 1.1386 - val_accuracy: 0.6238 - lr: 0.1000
# Epoch 7/60
# 351/351 [==============================] - 47s 134ms/step - loss: 0.9036 - accuracy: 0.6775 - val_loss: 0.9208 - val_accuracy: 0.6788 - lr: 0.1000
# Epoch 8/60
# 351/351 [==============================] - 47s 132ms/step - loss: 0.8595 - accuracy: 0.6947 - val_loss: 0.9018 - val_accuracy: 0.6814 - lr: 0.1000
# Epoch 9/60
# 351/351 [==============================] - 46s 132ms/step - loss: 0.8238 - accuracy: 0.7090 - val_loss: 0.9423 - val_accuracy: 0.6812 - lr: 0.1000
# Epoch 10/60
# 351/351 [==============================] - 47s 134ms/step - loss: 0.7942 - accuracy: 0.7187 - val_loss: 0.8880 - val_accuracy: 0.6928 - lr: 0.1000
# Epoch 11/60
# 351/351 [==============================] - 47s 134ms/step - loss: 0.7721 - accuracy: 0.7263 - val_loss: 0.8635 - val_accuracy: 0.6962 - lr: 0.1000
# Epoch 12/60
# 351/351 [==============================] - 47s 134ms/step - loss: 0