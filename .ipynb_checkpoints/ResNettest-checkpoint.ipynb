# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import *
from keras.models import Model
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
import numpy as np

# %%
np.random.seed(0)
tf.random.set_seed(0)

classes = 10
input_shape = (32, 32, 3)

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, classes)
y_test = keras.utils.to_categorical(y_test, classes)
datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=0,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True)
datagen.fit(x_train)
datagen_test = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True)
datagen_test.fit(x_train)

def split_data(images, labels, train_size=0.9, shuffle=True):
    # 1. Get the total size of the dataset
    size = len(images)
    # 2. Make an indices array and shuffle it, if required
    indices = np.arange(size)
    if shuffle:
        np.random.shuffle(indices)
    # 3. Get the size of training samples
    train_samples = int(size * train_size)
    # 4. Split data into training and validation sets
    x_train, y_train = images[indices[:train_samples]], labels[indices[:train_samples]]
    x_valid, y_valid = images[indices[train_samples:]], labels[indices[train_samples:]]
    return x_train, x_valid, y_train, y_valid


# Splitting data into training and validation sets
x_train, x_valid, y_train, y_valid = split_data(x_train, y_train)

# %%
# ResNet building block of two layers
def building_block(X, filter_size, filters, stride=1):

    # Save the input value for shortcut
    X_shortcut = X

    # Reshape shortcut for later adding if dimensions change
    if stride > 1:

        X_shortcut = Conv2D(filters, (1, 1), strides=stride, padding='same')(X_shortcut)
        X_shortcut = BatchNormalization(axis=3)(X_shortcut)

    # First layer of the block
    X = Conv2D(filters, kernel_size = filter_size, strides=stride, padding='same')(X)
    X = BatchNormalization(axis=3)(X)
    X = Activation('relu')(X)

    # Second layer of the block
    X = Conv2D(filters, kernel_size = filter_size, strides=(1, 1), padding='same')(X)
    X = BatchNormalization(axis=3)(X)
    X = add([X, X_shortcut])  # Add shortcut value to main path
    X = Activation('relu')(X)

    return X


# Full model
def create_model(input_shape, classes, name):

    # Define the input
    X_input = Input(input_shape)

    # Stage 1
    X = Conv2D(filters=16, kernel_size=3, strides=(1, 1), padding='same')(X_input)
    X = BatchNormalization(axis=3)(X)
    X = Activation('relu')(X)

    # Stage 2
    X = building_block(X, filter_size=3, filters=16, stride=1)
    X = building_block(X, filter_size=3, filters=16, stride=1)
    X = building_block(X, filter_size=3, filters=16, stride=1)
    X = building_block(X, filter_size=3, filters=16, stride=1)
    X = building_block(X, filter_size=3, filters=16, stride=1)

    # Stage 3
    X = building_block(X, filter_size=3, filters=32, stride=2)  # dimensions change (stride=2)
    X = building_block(X, filter_size=3, filters=32, stride=1)
    X = building_block(X, filter_size=3, filters=32, stride=1)
    X = building_block(X, filter_size=3, filters=32, stride=1)
    X = building_block(X, filter_size=3, filters=32, stride=1)

    # Stage 4
    X = building_block(X, filter_size=3, filters=64, stride=2)  # dimensions change (stride=2)
    X = building_block(X, filter_size=3, filters=64, stride=1)
    X = building_block(X, filter_size=3, filters=64, stride=1)
    X = building_block(X, filter_size=3, filters=64, stride=1)
    X = building_block(X, filter_size=3, filters=64, stride=1)

    # Average pooling and output layer
    X = GlobalAveragePooling2D()(X)
    X = Dense(classes, activation='softmax')(X)

    # Create model
    model = Model(inputs=X_input, outputs=X, name=name)

    return model

# %%
# Define optimizer and compile model
optimizer = keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
ResNet32 = create_model(input_shape=input_shape, classes=classes, name='ResNet32')
ResNet32.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics = ['accuracy'])

# %%
# Generator for data augmantation
datagen = ImageDataGenerator(
        rotation_range=30,  # randomly rotate images in the range (degrees, 0 to 180)
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True)  # randomly flip images

# %%
# Train model
results = ResNet32.fit(datagen.flow(x_train, y_train,
                                 batch_size = 250),
                                 epochs = 50,
                                 steps_per_epoch=len(x_train) / 250,  # data_size/batch size
                                 validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
#
# 180/180 [==============================] - 47s 259ms/step - loss: 0.3343 - accuracy: 0.8832 - val_loss: 0.5415 - val_accuracy: 0.8298
# Epoch 40/50
# 180/180 [==============================] - 51s 280ms/step - loss: 0.3313 - accuracy: 0.8849 - val_loss: 0.6540 - val_accuracy: 0.7924
# Epoch 41/50
# 180/180 [==============================] - 47s 261ms/step - loss: 0.3328 - accuracy: 0.8836 - val_loss: 0.6860 - val_accuracy: 0.7894
# Epoch 42/50
# 180/180 [==============================] - 49s 270ms/step - loss: 0.3239 - accuracy: 0.8876 - val_loss: 0.5270 - val_accuracy: 0.8331
# Epoch 43/50
# 180/180 [==============================] - 47s 259ms/step - loss: 0.3173 - accuracy: 0.8880 - val_loss: 0.5183 - val_accuracy: 0.8337
# Epoch 44/50
# 180/180 [==============================] - 47s 258ms/step - loss: 0.3084 - accuracy: 0.8912 - val_loss: 0.6882 - val_accuracy: 0.7982
# Epoch 45/50
# 180/180 [==============================] - 47s 260ms/step - loss: 0.3064 - accuracy: 0.8925 - val_loss: 0.6229 - val_accuracy: 0.8081
# Epoch 46/50
# 180/180 [==============================] - 47s 259ms/step - loss: 0.3039 - accuracy: 0.8943 - val_loss: 0.5406 - val_accuracy: 0.8366
# Epoch 47/50
# 180/180 [==============================] - 49s 271ms/step - loss: 0.3009 - accuracy: 0.8962 - val_loss: 0.5942 - val_accuracy: 0.8209
# Epoch 48/50
# 180/180 [==============================] - 48s 264ms/step - loss: 0.2993 - accuracy: 0.8951 - val_loss: 0.5107 - val_accuracy: 0.8388
# Epoch 49/50
# 180/180 [==============================] - 48s 267ms/step - loss: 0.2896 - accuracy: 0.8988 - val_loss: 0.4841 - val_accuracy: 0.8475
# Epoch 50/50
# 180/180 [==============================] - 49s 270ms/step - loss: 0.2885 - accuracy: 0.8983 - val_loss: 0.4348 - val_accuracy: 0.8623

# %%
# Plot train / validation results
plot_results(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19608/124768846.py in <module>
#       1 # Plot train / validation results
# ----> 2 plot_results(results)
#
# NameError: name 'plot_results' is not defined

# %%
# Print model architecture
ResNet32.summary()
# Out:
# Model: "ResNet32"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d_66 (Conv2D)             (None, 32, 32, 16)   448         ['input_3[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 32, 32, 16)  64          ['conv2d_66[0][0]']
#  ormalization)
#
#  activation_62 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_66[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_62[0][0]']
#
#  batch_normalization_67 (BatchN  (None, 32, 32, 16)  64          ['conv2d_67[0][0]']
#  ormalization)
#
#  activation_63 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_67[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_63[0][0]']
#
#  batch_normalization_68 (BatchN  (None, 32, 32, 16)  64          ['conv2d_68[0][0]']
#  ormalization)
#
#  add_30 (Add)                   (None, 32, 32, 16)   0           ['batch_normalization_68[0][0]',
#                                                                   'activation_62[0][0]']
#
#  activation_64 (Activation)     (None, 32, 32, 16)   0           ['add_30[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_64[0][0]']
#
#  batch_normalization_69 (BatchN  (None, 32, 32, 16)  64          ['conv2d_69[0][0]']
#  ormalization)
#
#  activation_65 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_69[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_65[0][0]']
#
#  batch_normalization_70 (BatchN  (None, 32, 32, 16)  64          ['conv2d_70[0][0]']
#  ormalization)
#
#  add_31 (Add)                   (None, 32, 32, 16)   0           ['batch_normalization_70[0][0]',
#                                                                   'activation_64[0][0]']
#
#  activation_66 (Activation)     (None, 32, 32, 16)   0           ['add_31[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_66[0][0]']
#
#  batch_normalization_71 (BatchN  (None, 32, 32, 16)  64          ['conv2d_71[0][0]']
#  ormalization)
#
#  activation_67 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_71[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_67[0][0]']
#
#  batch_normalization_72 (BatchN  (None, 32, 32, 16)  64          ['conv2d_72[0][0]']
#  ormalization)
#
#  add_32 (Add)                   (None, 32, 32, 16)   0           ['batch_normalization_72[0][0]',
#                                                                   'activation_66[0][0]']
#
#  activation_68 (Activation)     (None, 32, 32, 16)   0           ['add_32[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_68[0][0]']
#
#  batch_normalization_73 (BatchN  (None, 32, 32, 16)  64          ['conv2d_73[0][0]']
#  ormalization)
#
#  activation_69 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_73[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_69[0][0]']
#
#  batch_normalization_74 (BatchN  (None, 32, 32, 16)  64          ['conv2d_74[0][0]']
#  ormalization)
#
#  add_33 (Add)                   (None, 32, 32, 16)   0           ['batch_normalization_74[0][0]',
#                                                                   'activation_68[0][0]']
#
#  activation_70 (Activation)     (None, 32, 32, 16)   0           ['add_33[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_70[0][0]']
#
#  batch_normalization_75 (BatchN  (None, 32, 32, 16)  64          ['conv2d_75[0][0]']
#  ormalization)
#
#  activation_71 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_75[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_71[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 32, 32, 16)  64          ['conv2d_76[0][0]']
#  ormalization)
#
#  add_34 (Add)                   (None, 32, 32, 16)   0           ['batch_normalization_76[0][0]',
#                                                                   'activation_70[0][0]']
#
#  activation_72 (Activation)     (None, 32, 32, 16)   0           ['add_34[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 16, 16, 32)   4640        ['activation_72[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 16, 16, 32)  128         ['conv2d_78[0][0]']
#  ormalization)
#
#  activation_73 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_78[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_73[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 16, 16, 32)   544         ['activation_72[0][0]']
#
#  batch_normalization_79 (BatchN  (None, 16, 16, 32)  128         ['conv2d_79[0][0]']
#  ormalization)
#
#  batch_normalization_77 (BatchN  (None, 16, 16, 32)  128         ['conv2d_77[0][0]']
#  ormalization)
#
#  add_35 (Add)                   (None, 16, 16, 32)   0           ['batch_normalization_79[0][0]',
#                                                                   'batch_normalization_77[0][0]']
#
#  activation_74 (Activation)     (None, 16, 16, 32)   0           ['add_35[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_74[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 16, 16, 32)  128         ['conv2d_80[0][0]']
#  ormalization)
#
#  activation_75 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_80[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_75[0][0]']
#
#  batch_normalization_81 (BatchN  (None, 16, 16, 32)  128         ['conv2d_81[0][0]']
#  ormalization)
#
#  add_36 (Add)                   (None, 16, 16, 32)   0           ['batch_normalization_81[0][0]',
#                                                                   'activation_74[0][0]']
#
#  activation_76 (Activation)     (None, 16, 16, 32)   0           ['add_36[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_76[0][0]']
#
#  batch_normalization_82 (BatchN  (None, 16, 16, 32)  128         ['conv2d_82[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_82[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_77[0][0]']
#
#  batch_normalization_83 (BatchN  (None, 16, 16, 32)  128         ['conv2d_83[0][0]']
#  ormalization)
#
#  add_37 (Add)                   (None, 16, 16, 32)   0           ['batch_normalization_83[0][0]',
#                                                                   'activation_76[0][0]']
#
#  activation_78 (Activation)     (None, 16, 16, 32)   0           ['add_37[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_78[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 16, 16, 32)  128         ['conv2d_84[0][0]']
#  ormalization)
#
#  activation_79 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_84[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_79[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 16, 16, 32)  128         ['conv2d_85[0][0]']
#  ormalization)
#
#  add_38 (Add)                   (None, 16, 16, 32)   0           ['batch_normalization_85[0][0]',
#                                                                   'activation_78[0][0]']
#
#  activation_80 (Activation)     (None, 16, 16, 32)   0           ['add_38[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_80[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 16, 16, 32)  128         ['conv2d_86[0][0]']
#  ormalization)
#
#  activation_81 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_86[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_81[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 16, 16, 32)  128         ['conv2d_87[0][0]']
#  ormalization)
#
#  add_39 (Add)                   (None, 16, 16, 32)   0           ['batch_normalization_87[0][0]',
#                                                                   'activation_80[0][0]']
#
#  activation_82 (Activation)     (None, 16, 16, 32)   0           ['add_39[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 8, 8, 64)     18496       ['activation_82[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 8, 8, 64)    256         ['conv2d_89[0][0]']
#  ormalization)
#
#  activation_83 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_89[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_83[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 8, 8, 64)     2112        ['activation_82[0][0]']
#
#  batch_normalization_90 (BatchN  (None, 8, 8, 64)    256         ['conv2d_90[0][0]']
#  ormalization)
#
#  batch_normalization_88 (BatchN  (None, 8, 8, 64)    256         ['conv2d_88[0][0]']
#  ormalization)
#
#  add_40 (Add)                   (None, 8, 8, 64)     0           ['batch_normalization_90[0][0]',
#                                                                   'batch_normalization_88[0][0]']
#
#  activation_84 (Activation)     (None, 8, 8, 64)     0           ['add_40[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_84[0][0]']
#
#  batch_normalization_91 (BatchN  (None, 8, 8, 64)    256         ['conv2d_91[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_91[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_85[0][0]']
#
#  batch_normalization_92 (BatchN  (None, 8, 8, 64)    256         ['conv2d_92[0][0]']
#  ormalization)
#
#  add_41 (Add)                   (None, 8, 8, 64)     0           ['batch_normalization_92[0][0]',
#                                                                   'activation_84[0][0]']
#
#  activation_86 (Activation)     (None, 8, 8, 64)     0           ['add_41[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_86[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 8, 8, 64)    256         ['conv2d_93[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_93[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_87[0][0]']
#
#  batch_normalization_94 (BatchN  (None, 8, 8, 64)    256         ['conv2d_94[0][0]']
#  ormalization)
#
#  add_42 (Add)                   (None, 8, 8, 64)     0           ['batch_normalization_94[0][0]',
#                                                                   'activation_86[0][0]']
#
#  activation_88 (Activation)     (None, 8, 8, 64)     0           ['add_42[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_88[0][0]']
#
#  batch_normalization_95 (BatchN  (None, 8, 8, 64)    256         ['conv2d_95[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_95[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_89[0][0]']
#
#  batch_normalization_96 (BatchN  (None, 8, 8, 64)    256         ['conv2d_96[0][0]']
#  ormalization)
#
#  add_43 (Add)                   (None, 8, 8, 64)     0           ['batch_normalization_96[0][0]',
#                                                                   'activation_88[0][0]']
#
#  activation_90 (Activation)     (None, 8, 8, 64)     0           ['add_43[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_90[0][0]']
#
#  batch_normalization_97 (BatchN  (None, 8, 8, 64)    256         ['conv2d_97[0][0]']
#  ormalization)
#
#  activation_91 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_97[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_91[0][0]']
#
#  batch_normalization_98 (BatchN  (None, 8, 8, 64)    256         ['conv2d_98[0][0]']
#  ormalization)
#
#  add_44 (Add)                   (None, 8, 8, 64)     0           ['batch_normalization_98[0][0]',
#                                                                   'activation_90[0][0]']
#
#  activation_92 (Activation)     (None, 8, 8, 64)     0           ['add_44[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 64)          0           ['activation_92[0][0]']
#  obalAveragePooling2D)
#
#  dense_2 (Dense)                (None, 10)           650         ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 470,602
# Trainable params: 468,138
# Non-trainable params: 2,464
# __________________________________________________________________________________________________

# %%
ResNet32.fit?

# %%
len(x_train) / 250
# Out:
# 180.0

# %%
Conv2D?
